# %% [markdown]
# <a href="https://colab.research.google.com/github/rizanatlanta-dsproj/movie-recommendation-system/blob/main/movie_rec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the dependencies

# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Data collection and pre-processing

# %%
movies_data = pd.read_csv('/content/drive/MyDrive/movies.csv', engine='python', on_bad_lines='skip')

# %%
# printing the first 5 rows from the dataframe
movies_data.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
# numbers of rows and columns in the dataframe
movies_data.shape
# Out:
# (3183, 24)

# %%
# selecting the relevant features for recommendation
selected_features = ['genres','keywords','tagline','cast','director']
print(selected_features)
# Out:
# ['genres', 'keywords', 'tagline', 'cast', 'director']

# %%
# replacing the null values with the null string

for feature in selected_features:
 movies_data[feature] = movies_data[feature].fillna(' ')

# %%
# combining all the 5 selected features

combined_features = movies_data['genres']+' '+movies_data['keywords']+' '+movies_data['tagline']+' '+movies_data['cast']+' '+movies_data['director']

# %%
print(combined_features)
# Out:
# 0       Action Adventure Fantasy Science Fiction cultu...
# 1       Adventure Fantasy Action ocean drug abuse exot...
# 2       Action Adventure Crime spy based on novel secr...
# 3       Action Crime Drama Thriller dc comics crime fi...
# 4       Action Adventure Science Fiction based on nove...
#                               ...
# 3178    Drama father son relationship depression paren...
# 3179    Comedy Romance woman director Three women. Thr...
# 3180    Action Crime Drama Thriller gunslinger mexico ...
# 3181    Comedy Drama father son relationship patenonke...
# 3182    Comedy mascot beer keg political correctness u...
# Length: 3183, dtype: object

# %%
# converting the text data to feature vectors

vectorizer = TfidfVectorizer()

# %%
feature_vectors = vectorizer.fit_transform(combined_features)

# %%
print(feature_vectors)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 86255 stored elements and shape (3183, 12528)>
#   Coords	Values
#   (0, 144)	0.07358439072539939
#   (0, 201)	0.08327906224287762
#   (0, 3797)	0.10524915533967356
#   (0, 9801)	0.10126335133455207
#   (0, 3918)	0.10134338898491221
#   (0, 2625)	0.24307030428588336
#   (0, 2177)	0.23791925094385474
#   (0, 4221)	0.16449744693391993
#   (0, 10378)	0.3322556091431109
#   (0, 11974)	0.1237918596737988
#   (0, 2290)	0.24916270728728288
#   (0, 10295)	0.21475725058847475
#   (0, 3552)	0.23345720558009075
#   (0, 11013)	0.07010562188102334
#   (0, 12304)	0.12539869340828064
#   (0, 8055)	0.09149075016338687
#   (0, 8272)	0.26623230464126335
#   (0, 9630)	0.14973329488609874
#   (0, 12310)	0.22952140263629597
#   (0, 12508)	0.20455270807022194
#   (0, 9606)	0.21245180528231547
#   (0, 10138)	0.19965384991056087
#   (0, 12041)	0.19407162022420452
#   (0, 10549)	0.15528454107181178
#   (0, 6326)	0.23345720558009075
#   :	:
# ...

# %% [markdown]
# Cosine Similarity

# %%
# getting the similarity scores using cosine similarity

similarity = cosine_similarity(feature_vectors)

# %%
print(similarity)
# Out:
# [[1.         0.06825004 0.03608013 ... 0.02055296 0.         0.        ]
#  [0.06825004 1.         0.03038509 ... 0.00514931 0.01213283 0.        ]
#  [0.03608013 0.03038509 1.         ... 0.01610034 0.         0.        ]
#  ...
#  [0.02055296 0.00514931 0.01610034 ... 1.         0.00397341 0.        ]
#  [0.         0.01213283 0.         ... 0.00397341 1.         0.0038337 ]
#  [0.         0.         0.         ... 0.         0.0038337  1.        ]]

# %%
print(similarity.shape)
# Out:
# (3183, 3183)

# %%
# getting the movie name from the user

movie_name = input(' Enter your favourite movie name : ')
# Out:
#  Enter your favourite movie name : Iron man

# %%
# creating a list with all the movie names in the dataset

list_of_all_titles = movies_data['title'].tolist()
print(list_of_all_titles)
# Out:
# ['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre', 'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'Superman Returns', 'Quantum of Solace', "Pirates of the Caribbean: Dead Man's Chest", 'The Lone Ranger', 'Man of Steel', 'The Chronicles of Narnia: Prince Caspian', 'The Avengers', 'Pirates of the Caribbean: On Stranger Tides', 'Men in Black 3', 'The Hobbit: The Battle of the Five Armies', 'The Amazing Spider-Man', 'Robin Hood', 'The Hobbit: The Desolation of Smaug', 'The Golden Compass', 'King Kong', 'Titanic', 'Captain America: Civil War', 'Battleship', 'Jurassic World', 'Skyfall', 'Spider-Man 2', 'Iron Man 3', 'Alice in Wonderland', 'X-Men: The Last Stand', 'Monsters University', 'Transformers: Revenge of the Fallen', 'Transformers: Age of Extinction', 'Oz: The Great and Powerful', 'The Amazing Spider-Man 2', 'TRON: Legacy', 'Cars 2', 'Green La
# ...

# %%
#finding the close match for the movie name given by the user

find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
print(find_close_match)
# Out:
# ['Iron Man', 'Iron Man 3', 'Iron Man 2']

# %%
close_match = find_close_match[0]
print(close_match)
# Out:
# Iron Man

# %%
# finding the index of the movie with title

index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]
print(index_of_the_movie)
# Out:
# 68

# %%
# getting a list of similar movies

similarity_score = list(enumerate(similarity[index_of_the_movie]))
print(similarity_score)
# Out:
# [(0, np.float64(0.030935728212631457)), (1, np.float64(0.05503672614119809)), (2, np.float64(0.012059465835744429)), (3, np.float64(0.00573073828450746)), (4, np.float64(0.02975649867873662)), (5, np.float64(0.01214878716314597)), (6, np.float64(0.07759516180016587)), (7, np.float64(0.23227114953796532)), (8, np.float64(0.006766446360175982)), (9, np.float64(0.07206523867832214)), (10, np.float64(0.07181381421434829)), (11, np.float64(0.010324162420858589)), (12, np.float64(0.011971318193701706)), (13, np.float64(0.010575206379085251)), (14, np.float64(0.09229079117074068)), (15, np.float64(0.006206684022580139)), (16, np.float64(0.22091846076775412)), (17, np.float64(0.011405249480225473)), (18, np.float64(0.03984993686557413)), (19, np.float64(0.07903336110187752)), (20, np.float64(0.07332322382742568)), (21, np.float64(0.009818351597786103)), (22, np.float64(0.005984743244866186)), (23, np.float64(0.005677500411766676)), (24, np.float64(0.010592779087273626)), (25, np.float64(0.0)
# ...

# %%
len(similarity_score)
# Out:
# 3183

# %%
# sorting the movies based on their similarity score

sorted_similar_movies = sorted(similarity_score, key = lambda x:x[1], reverse = True)
print(sorted_similar_movies)
# Out:
# [(68, np.float64(1.0000000000000002)), (79, np.float64(0.3979305192786538)), (31, np.float64(0.3045833265482917)), (7, np.float64(0.23227114953796532)), (16, np.float64(0.22091846076775412)), (26, np.float64(0.2092562627697605)), (85, np.float64(0.19977084949783164)), (182, np.float64(0.1876931636678134)), (511, np.float64(0.1596005143165733)), (64, np.float64(0.14520716170450115)), (203, np.float64(0.14050130775632108)), (174, np.float64(0.13802880106855986)), (101, np.float64(0.13563827694407243)), (46, np.float64(0.134681149772915)), (169, np.float64(0.1297900742040666)), (1740, np.float64(0.129529467403979)), (94, np.float64(0.12901523895671693)), (131, np.float64(0.12881710001130936)), (126, np.float64(0.1266014511027932)), (788, np.float64(0.12580611238936668)), (33, np.float64(0.12327160842821776)), (783, np.float64(0.12243053861640985)), (2487, np.float64(0.12008955306595437)), (138, np.float64(0.11834922206666913)), (2442, np.float64(0.11834398784317654)), (661, np.float64(0
# ...

# %%
# print the name of the similar movies based on the index

print('Movies suggested for you : \n')

i = 1

for movie in sorted_similar_movies:
  index = movie[0]
  title_from_index = movies_data[movies_data.index==index]['title'].values[0]
  if (i<30):
    print(i, '.',title_from_index)
    i+=1
# Out:
# Movies suggested for you :
#
# 1 . Iron Man
# 2 . Iron Man 2
# 3 . Iron Man 3
# 4 . Avengers: Age of Ultron
# 5 . The Avengers
# 6 . Captain America: Civil War
# 7 . Captain America: The Winter Soldier
# 8 . Ant-Man
# 9 . X-Men
# 10 . X-Men: Apocalypse
# 11 . X2
# 12 . The Incredible Hulk
# 13 . X-Men: First Class
# 14 . X-Men: Days of Future Past
# 15 . Captain America: The First Avenger
# 16 . Kick-Ass 2
# 17 . Guardians of the Galaxy
# 18 . G-Force
# 19 . Thor: The Dark World
# 20 . Deadpool
# 21 . X-Men: The Last Stand
# 22 . Mortdecai
# 23 . Duets
# 24 . The Last Airbender
# 25 . Southland Tales
# 26 . Zathura: A Space Adventure
# 27 . The Good Night
# 28 . Sky Captain and the World of Tomorrow
# 29 . Tropic Thunder

# %% [markdown]
# Rizan's Movie Recommendation System

# %%
smovie_name = input(' Enter your favourite movie : ')

list_of_all_titles = movies_data['title'].tolist()

find_close_match = difflib.get_close_matches(smovie_name, list_of_all_titles)

close_match = find_close_match[0]

index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]

similarity_score = list(enumerate(similarity[index_of_the_movie]))

sorted_similar_movies = sorted(similarity_score, key = lambda x:x[1], reverse = True)

print('Movies suggested for you : \n')

i=1

for movie in sorted_similar_movies:
  index = movie[0]
  title_from_index = movies_data[movies_data.index==index]['title'].values[0]
  if (i<30):
    print(i, '.',title_from_index)
    i+=1
# Out:
#  Enter your favourite movie : avatar
# Movies suggested for you :
#
# 1 . Avatar
# 2 . Aliens
# 3 . Alien
# 4 . Guardians of the Galaxy
# 5 . Star Trek Beyond
# 6 . Star Trek Into Darkness
# 7 . Galaxy Quest
# 8 . Pocahontas
# 9 . Alien³
# 10 . Gravity
# 11 . Moonraker
# 12 . Jason X
# 13 . Space Cowboys
# 14 . Lockout
# 15 . Gettysburg
# 16 . Clash of the Titans
# 17 . Space Dogs
# 18 . Event Horizon
# 19 . Machete Kills
# 20 . The Right Stuff
# 21 . Terminator Salvation
# 22 . The Astronaut's Wife
# 23 . Star Trek
# 24 . Planet of the Apes
# 25 . Wing Commander
# 26 . Sunshine
# 27 . Shadow Conspiracy
# 28 . Supernova
# 29 . Zathura: A Space Adventure

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# After running the cell above and following the authentication steps, your Google Drive will be mounted. Then, you'll need to update the path to your `movies.csv` file in your data loading cell (`qCnsFTQwWmr1`) to point to where it's stored in your Google Drive. For example, if your file is directly in your Drive's root, the path might look like `/content/drive/MyDrive/movies.csv`.
